# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Activation

from sklearn.preprocessing import MinMaxScaler

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
print(os.listdir("../input"))

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# ['dataaa', 'googledta']

# %%
train = pd.read_csv('../input/dataaa/Download Data - STOCK_PH_XPHS_BLOOM (2).csv')
test = pd.read_csv('../input/dataaa/Download Data - STOCK_PH_XPHS_BLOOM (2).csv')

# %% [markdown]
# Hyperparameters

# %%
metric = 'Open' # What matric to model and predict
timestamp = 64 # Maximum number of timestamps to learn from
layers = 3 # Number of layers in LSTM
neurons = 264 # Number of neurons in each layer
epochs = 64 # Number of times the entire data needs to be looped upon
batch_size = 16 # Weights updated after n rows
validation_split = 0.1 # Percentage of data to validate the model when training
dropout = 0.2 # Regularisation parameter
optimizer = 'adam' 
loss = 'mean_squared_error'

# %%
loc = train.columns.get_loc(metric)
train_data = train.iloc[:,loc:loc + 1].values

# %%
sc = MinMaxScaler(feature_range = (0,1))

train_data = sc.fit_transform(train_data)

# %%
train_x = []
train_y = []
for i in range(0, len(train_data) - timestamp - 1):
    train_x.append(train_data[i : i + timestamp, 0])
    train_y.append(train_data[i + timestamp, 0])
train_x, train_y = np.array(train_x), np.array(train_y)

# %%
train_x = np.reshape(train_x, (train_x.shape[0],train_x.shape[1],1))

# %%
regressor = Sequential()
regressor.add(LSTM(neurons, return_sequences = True, input_shape = (train_x.shape[1],1)))
regressor.add(Dropout(dropout))

if layers > 2:
    for i in range(2,layers):
        regressor.add(LSTM(neurons, return_sequences = True))
        regressor.add(Dropout(dropout))

regressor.add(LSTM(neurons))
regressor.add(Dropout(dropout))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = optimizer,loss = loss)

# %%
regressor.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 64, 264)           280896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 264)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64, 264)           558624
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 264)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 264)               558624
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 264)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 265
# =================================================================
# Total params: 1,398,409
# Trainable params: 1,398,409
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressor.fit(train_x,train_y,epochs = epochs, batch_size = batch_size, validation_split = validation_split)
# Out:
# Train on 165 samples, validate on 19 samples
# Epoch 1/64
# 165/165 [==============================] - 7s 39ms/step - loss: 0.0737 - val_loss: 0.1739
# Epoch 2/64
# 165/165 [==============================] - 4s 22ms/step - loss: 0.0254 - val_loss: 0.0729
# Epoch 3/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0228 - val_loss: 0.0211
# Epoch 4/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0202 - val_loss: 0.0076
# Epoch 5/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0195 - val_loss: 0.0081
# Epoch 6/64
# 165/165 [==============================] - 4s 25ms/step - loss: 0.0165 - val_loss: 0.0182
# Epoch 7/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0177 - val_loss: 0.0251
# Epoch 8/64
# 165/165 [==============================] - 4s 22ms/step - loss: 0.0172 - val_loss: 0.0146
# Epoch 9/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0162 - val_loss: 0.0255
# Epoch 10/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0155 - val_loss: 0.0444
# Epoch 11/64
# 165/165 [==============================] - 4s 22ms/step - loss: 0.0197 - val_loss: 0.0184
# Epoch 12/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0179 - val_loss: 0.0072
# Epoch 13/64
# 165/165 [==============================] - 4s 22ms/step - loss: 0.0164 - val_loss: 0.0060
# Epoch 14/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0158 - val_loss: 0.0092
# Epoch 15/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0131 - val_loss: 0.0189
# Epoch 16/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0136 - val_loss: 0.0094
# Epoch 17/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0131 - val_loss: 0.0183
# Epoch 18/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0141 - val_loss: 0.0056
# Epoch 19/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0146 - val_loss: 0.0056
# Epoch 20/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0152 - val_loss: 0.0059
# Epoch 21/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0160 - val_loss: 0.0245
# Epoch 22/64
# 165/165 [==============================] - 4s 25ms/step - loss: 0.0125 - val_loss: 0.0112
# Epoch 23/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0125 - val_loss: 0.0063
# Epoch 24/64
# 165/165 [==============================] - 4s 22ms/step - loss: 0.0159 - val_loss: 0.0209
# Epoch 25/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0136 - val_loss: 0.0117
# Epoch 26/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0123 - val_loss: 0.0154
# Epoch 27/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0113 - val_loss: 0.0131
# Epoch 28/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0128 - val_loss: 0.0056
# Epoch 29/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0118 - val_loss: 0.0092
# Epoch 30/64
# 165/165 [==============================] - 4s 25ms/step - loss: 0.0107 - val_loss: 0.0173
# Epoch 31/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0111 - val_loss: 0.0082
# Epoch 32/64
# 165/165 [==============================] - 4s 22ms/step - loss: 0.0120 - val_loss: 0.0095
# Epoch 33/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0138 - val_loss: 0.0076
# Epoch 34/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0135 - val_loss: 0.0162
# Epoch 35/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0110 - val_loss: 0.0094
# Epoch 36/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0092 - val_loss: 0.0062
# Epoch 37/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0104 - val_loss: 0.0118
# Epoch 38/64
# 165/165 [==============================] - 4s 26ms/step - loss: 0.0097 - val_loss: 0.0059
# Epoch 39/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0089 - val_loss: 0.0105
# Epoch 40/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0083 - val_loss: 0.0059
# Epoch 41/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0080 - val_loss: 0.0059
# Epoch 42/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0090 - val_loss: 0.0074
# Epoch 43/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0106 - val_loss: 0.0057
# Epoch 44/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0101 - val_loss: 0.0236
# Epoch 45/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0106 - val_loss: 0.0061
# Epoch 46/64
# 165/165 [==============================] - 4s 25ms/step - loss: 0.0087 - val_loss: 0.0087
# Epoch 47/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0087 - val_loss: 0.0072
# Epoch 48/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0086 - val_loss: 0.0069
# Epoch 49/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0083 - val_loss: 0.0118
# Epoch 50/64
# 165/165 [==============================] - 4s 25ms/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 51/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0086 - val_loss: 0.0077
# Epoch 52/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0082 - val_loss: 0.0139
# Epoch 53/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0079 - val_loss: 0.0101
# Epoch 54/64
# 165/165 [==============================] - 4s 25ms/step - loss: 0.0078 - val_loss: 0.0087
# Epoch 55/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0077 - val_loss: 0.0094
# Epoch 56/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0092 - val_loss: 0.0064
# Epoch 57/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0082 - val_loss: 0.0066
# Epoch 58/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0090 - val_loss: 0.0067
# Epoch 59/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0088 - val_loss: 0.0085
# Epoch 60/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0094 - val_loss: 0.0119
# Epoch 61/64
# 165/165 [==============================] - 4s 23ms/step - loss: 0.0086 - val_loss: 0.0193
# Epoch 62/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0110 - val_loss: 0.0077
# Epoch 63/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0077 - val_loss: 0.0071
# Epoch 64/64
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0078 - val_loss: 0.0083

# %%
test_data = pd.concat((train[len(train) - timestamp:][metric], test[metric]), axis = 0)
test_data = test_data.values
test_data = test_data.reshape(-1,1)

# %%
test_data = sc.transform(test_data)

# %%
test_x = []
test_y = []
for i in range(0, len(test_data) - timestamp - 1):
    test_x.append(test_data[i : i + timestamp, 0])
    test_y.append(test_data[i + timestamp, 0])
test_x, test_y = np.array(test_x), np.array(test_y)

# %%
test_x = np.reshape(test_x, (test_x.shape[0],test_x.shape[1],1))

# %%
predicted_price = sc.inverse_transform(regressor.predict(test_x))
real_stock_price = test[metric]

# %%
def plot_pred(metric, real_stock_price, predicted_price):
    plt.plot(real_stock_price,color = 'blue', label = 'Real Price')
    plt.plot(predicted_price, color = 'pink', label = 'Predicted Price')
    plt.title('Bloomberry Resorts ' +metric+ ' Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('Bloomberry Resorts ' +metric+ ' Stock Price')
    plt.legend()
    plt.show()

plot_pred(metric, real_stock_price, predicted_price)
